# %% [markdown]
# <a href="https://colab.research.google.com/github/luisfelipemisi/ProjetoComun/blob/main/figerprint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Fingerprinting-based technique
# ![fingerprint.png](data:image/png;base64,...)

# %% [markdown]
# ## **Esse método consiste em ter um banco de dados com informações sobre a comunição de diversos dispositivos em locais difentes como referência para que outras informações similadores possam ser comparadas e então definina a posição mais próxima do real.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("LocTreino_Equipe_2.csv")

# %%
df.head()
# Out:
#    pontoId       lat        lon    pathBTS1    pathBTS2    pathBTS3  \
# 0     2818 -8.062787 -34.897289  131.790000  105.090000  125.656667
# 1      212 -8.076408 -34.899723  120.590000  112.123333  124.856667
# 2      500 -8.074771 -34.890739  118.723333  128.556667  130.090000
# 3     2094 -8.068030 -34.896683  111.490000  109.723333  108.056667
# 4     1790 -8.069077 -34.900505  123.290000  114.340000  121.790000
#
#      pathBTS4    pathBTS5    pathBTS6  taBTS1  taBTS2  taBTS3  taBTS4  taBTS5  \
# 0  105.756667  128.490000  115.990000     1.0       2       3       2       1
# 1  132.023333  135.523333  141.190000     2.0       1       1       1       2
# 2   98.956667  128.590000  146.423333     1.0       0       3       0       1
# 3   97.356667  118.456667   99.723333     0.0       1       2       1       1
# 4  126.090000  130.090000  109.040000     1.0       1       2       1       2
#
#    taBTS6
# 0       0
# 1       2
# 2       2
# 3       0
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pontoId   1500 non-null   int64
#  1   lat       1500 non-null   float64
#  2   lon       1500 non-null   float64
#  3   pathBTS1  1499 non-null   float64
#  4   pathBTS2  1500 non-null   float64
#  5   pathBTS3  1500 non-null   float64
#  6   pathBTS4  1500 non-null   float64
#  7   pathBTS5  1500 non-null   float64
#  8   pathBTS6  1500 non-null   float64
#  9   taBTS1    1498 non-null   float64
#  10  taBTS2    1500 non-null   int64
#  11  taBTS3    1500 non-null   int64
#  12  taBTS4    1500 non-null   int64
#  13  taBTS5    1500 non-null   int64
#  14  taBTS6    1500 non-null   int64
# dtypes: float64(9), int64(6)
# memory usage: 175.9 KB

# %%
df.describe(include="all")
# Out:
#            pontoId          lat          lon     pathBTS1     pathBTS2  \
# count  1500.000000  1500.000000  1500.000000  1499.000000  1500.000000
# mean   1469.771333    -8.070093   -34.895121   116.968673   118.576994
# std     856.004064     0.004283     0.004303    16.264039    12.287127
# min       2.000000    -8.077570   -34.906830    85.590000    77.256667
# 25%     722.500000    -8.073277   -34.898058   106.848333   111.190000
# 50%    1442.000000    -8.069987   -34.895710   117.223333   119.556667
# 75%    2234.250000    -8.066893   -34.891973   125.106667   127.852500
# max    2956.000000    -8.059338   -34.885067   447.512253   143.423333
#
#           pathBTS3     pathBTS4     pathBTS5     pathBTS6       taBTS1  \
# count  1500.000000  1500.000000  1500.000000  1500.000000  1498.000000
# mean    123.354330   117.328507   121.944930   124.915026     0.705356
# std       9.369300    29.580673    12.255739    13.453872     0.985407
# min      88.340000    84.656667    80.790000    88.556667     0.000000
# 25%     118.815000   106.956667   113.990000   114.452500     0.000000
# 50%     123.806667   116.248333   123.573333   128.506667     1.000000
# 75%     129.898333   125.965000   130.679583   135.802500     1.000000
# max     144.790000   683.059509   146.590000   149.756667    20.160818
#
#             taBTS2       taBTS3       taBTS4       taBTS5       taBTS6
# count  1500.000000  1500.000000  1500.000000  1500.000000  1500.000000
# mean      1.016667     2.480000     1.016667     1.137333     1.062000
# std       0.834777     0.956143     0.834777     0.835227     0.682006
# min       0.000000     1.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     1.000000     1.000000
# 50%       1.000000     2.000000     1.000000     1.000000     1.000000
# 75%       1.000000     3.000000     1.000000     2.000000     2.000000
# max       4.000000     5.000000     4.000000     3.000000     2.000000

# %%
plt.scatter(df.lon, df.lat)

# %%
fig1, ax1 = plt.subplots()
data = [df.taBTS1,df.taBTS2,df.taBTS3,df.taBTS4,df.taBTS5,df.taBTS6]
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f39ae5ecfd0>,
#   <matplotlib.lines.Line2D at 0x7f39ae503e10>,
#   <matplotlib.lines.Line2D at 0x7f39ae730f50>,
#   <matplotlib.lines.Line2D at 0x7f39ae7301d0>,
#   <matplotlib.lines.Line2D at 0x7f39ae68a4d0>,
#   <matplotlib.lines.Line2D at 0x7f39ae5c2c10>,
#   <matplotlib.lines.Line2D at 0x7f39ae57e850>,
#   <matplotlib.lines.Line2D at 0x7f39a4c47550>,
#   <matplotlib.lines.Line2D at 0x7f39ae5cad10>,
#   <matplotlib.lines.Line2D at 0x7f39ae5ca450>,
#   <matplotlib.lines.Line2D at 0x7f39a4ab9410>,
#   <matplotlib.lines.Line2D at 0x7f39ae72fa90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f39ae640d50>,
#   <matplotlib.lines.Line2D at 0x7f39ae5da110>,
#   <matplotlib.lines.Line2D at 0x7f39ae5b3850>,
#   <matplotlib.lines.Line2D at 0x7f39a50aa550>,
#   <matplotlib.lines.Line2D at 0x7f39ae617d90>,
#   <matplotlib.lines.Line2D at 0x7f39ae5e4110>,
#   <matplotlib.lines.Line2D at 0x7f39ae750890>,
#   <matplotlib.lines.Line2D at 0x7f39a4d36710>,
#   <matplotlib.lines.Line2D at 0x7f39ae6fd790>,
#   <matplotlib.lines.Line2D at 0x7f39ae6fd5d0>,
#   <matplotlib.lines.Line2D at 0x7f39a4ef4f10>,
#   <matplotlib.lines.Line2D at 0x7f39a55874d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f39a51ab810>,
#   <matplotlib.lines.Line2D at 0x7f39ae67f5d0>,
#   <matplotlib.lines.Line2D at 0x7f39ae68a410>,
#   <matplotlib.lines.Line2D at 0x7f39aed30c50>,
#   <matplotlib.lines.Line2D at 0x7f39aec29050>,
#   <matplotlib.lines.Line2D at 0x7f39ae6bf590>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f39ae6d33d0>,
#   <matplotlib.lines.Line2D at 0x7f39ae6be110>,
#   <matplotlib.lines.Line2D at 0x7f39ae57e690>,
#   <matplotlib.lines.Line2D at 0x7f39ae554590>,
#   <matplotlib.lines.Line2D at 0x7f39a51b4810>,
#   <matplotlib.lines.Line2D at 0x7f39ae6e7090>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f39a568fe10>,
#   <matplotlib.lines.Line2D at 0x7f39ae71a8d0>,
#   <matplotlib.lines.Line2D at 0x7f39ae5396d0>,
#   <matplotlib.lines.Line2D at 0x7f39a501ec90>,
#   <matplotlib.lines.Line2D at 0x7f39ae6e2390>,
#   <matplotlib.lines.Line2D at 0x7f39a4ad3350>],
#  'means': []}

# %%
fig, axs = plt.subplots(1, 6,figsize=(30,10))
for i, ax in enumerate(axs):
  ax.set_title(f'BTS{i+1}')
  ax.boxplot(df[f'pathBTS{i+1}'])

# %% [markdown]
# ###Split Data in test and train

# %%
df.sample(frac=1)
x_train = df.loc[:len(df)*0.8,['pathBTS1',	'pathBTS2',	'pathBTS3',	'pathBTS4',	'pathBTS5',	'pathBTS6']]
Y_train = df.loc[:len(df)*0.8,['lat','lon']]
x_test = df.loc[len(df)*0.8:,['pathBTS1',	'pathBTS2',	'pathBTS3',	'pathBTS4',	'pathBTS5',	'pathBTS6']]
Y_test = df.loc[len(df)*0.8:,['lat','lon']]

# %% [markdown]
# # Fingerprinting-based technique

# %%
import numpy as np 

def distance(v,w):
  sum_sq = np.sum(np.square(w - v)) 
  return np.sqrt(sum_sq)

# %%
def fingerprint(paths,df):
  df['distance'] = [distance(np.array(w),np.array(paths)) for w in df.values.tolist()]
  df = df.sort_values(by='distance',ascending=True)
  df = df.reset_index()
  return df.loc[0]

# %%
c = x_test.values.tolist()
Y_pred = []
for v in c:
  df = x_train.copy()
  resultado = fingerprint(v,df)
  df['lat'] = Y_train['lat']
  df['lon'] = Y_train['lon']
  num = resultado['index']
  vvv = df.values[num.astype(np.int64)]
  Y_pred.append([vvv[7], vvv[8]])

# %%
print(Y_pred)
# Out:
# [[-8.074966, -34.900185], [-8.06306, -34.888618], [-8.075004, -34.900188], [-8.076403, -34.895988], [-8.067201, -34.89677], [-8.065565, -34.887104], [-8.065721, -34.887669], [-8.077502, -34.899303], [-8.065859, -34.888054], [-8.068743, -34.891083], [-8.068251, -34.89185], [-8.077023, -34.897827], [-8.066042, -34.888721], [-8.065372, -34.889526], [-8.06353, -34.888889], [-8.069596, -34.894943], [-8.066914, -34.893795], [-8.071685, -34.891964], [-8.071407, -34.900791], [-8.063861, -34.894207], [-8.063926, -34.89463], [-8.072271, -34.89658], [-8.065111, -34.885826], [-8.072403, -34.893414], [-8.070419, -34.893299], [-8.072382, -34.900692], [-8.066232, -34.893524], [-8.077023, -34.897827], [-8.069701, -34.894749], [-8.070743, -34.892551], [-8.063289, -34.886677], [-8.064565, -34.897106], [-8.064293, -34.893597], [-8.075448, -34.89291], [-8.072039, -34.897087], [-8.075533, -34.896263], [-8.064722, -34.897087], [-8.060699, -34.905231], [-8.076776, -34.896996], [-8.075912, -34.899868], [-8.072952, -34.890656], [-8.074279, -34.890247], [-8.068839, -34.888863], [-8.068603, -34.896492], [-8.065797, -34.890648], [-8.06085, -34.905071], [-8.076448, -34.895847], [-8
# %%
df2 = Y_test.copy()
df2['lat_pred'] = [lat for lat,_ in Y_pred]
df2['lon_pred'] = [lon for _,lon in Y_pred]

# %%
df2.head()
# Out:
#            lat        lon  lat_pred   lon_pred
# 1200 -8.074966 -34.900185 -8.074966 -34.900185
# 1201 -8.062904 -34.888542 -8.063060 -34.888618
# 1202 -8.076345 -34.899746 -8.075004 -34.900188
# 1203 -8.076400 -34.895985 -8.076403 -34.895988
# 1204 -8.066894 -34.896820 -8.067201 -34.896770

# %%
df2['lat_diff'] = df2['lat'] - df2['lat_pred']
df2['lon_diff'] = df2['lon'] - df2['lon_pred']

# %%
df2.head()
# Out:
#            lat        lon  lat_pred   lon_pred  lat_diff  lon_diff
# 1200 -8.074966 -34.900185 -8.074966 -34.900185  0.000000  0.000000
# 1201 -8.062904 -34.888542 -8.063060 -34.888618  0.000156  0.000076
# 1202 -8.076345 -34.899746 -8.075004 -34.900188 -0.001341  0.000442
# 1203 -8.076400 -34.895985 -8.076403 -34.895988  0.000003  0.000003
# 1204 -8.066894 -34.896820 -8.067201 -34.896770  0.000307 -0.000050

# %%
df2.describe()
# Out:
#               lat         lon    lat_pred    lon_pred    lat_diff    lon_diff
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean    -8.070257  -34.894829   -8.070330  -34.894739    0.000073   -0.000091
# std      0.004200    0.004195    0.004243    0.004190    0.000871    0.001309
# min     -8.077546  -34.905945   -8.077502  -34.905231   -0.005252   -0.009456
# 25%     -8.073225  -34.897279   -8.073432  -34.897035   -0.000124   -0.000178
# 50%     -8.070200  -34.895453   -8.070481  -34.895611    0.000025    0.000000
# 75%     -8.067098  -34.891876   -8.067201  -34.891680    0.000201    0.000112
# max     -8.060065  -34.885067   -8.060699  -34.885086    0.004206    0.015182

# %%
df2['lat_diff_metros'] = df2['lat_diff'] * 30.87 * 1000
df2['lon_diff_metros'] = df2['lon_diff'] * 30.87 * 1000

# %%
import math
df2['diff_metros'] = [math.sqrt(lat_diff**2+lon_diff**2) for lat_diff,lon_diff in zip(df2['lat_diff_metros'],df2['lon_diff_metros'])]

# %%
df2['diff_metros'].describe()
# Out:
# count    300.000000
# mean      24.136213
# std       42.229110
# min        0.000000
# 25%        3.143914
# 50%        9.506368
# 75%       28.402496
# max      479.895744
# Name: diff_metros, dtype: float64

# %%
df2['diff_metros'].hist(bins=100,figsize=(30,10))

# %%
df2['diff_metros'].plot(kind='box',figsize=(10,15))

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3,figsize=(15,15))
ax1.scatter(df2['lon'],df2['lat'], c='green')
ax1.scatter(df2['lon_pred'],df2['lat_pred'], c='red')
#ax1.title('Mapa de comparação:')
ax1.legend(["reais","preditas"])

ax2.scatter(df2['lon'],df2['lat'], c='green')
#ax2.title('Reais:')

ax3.scatter(df2['lon_pred'],df2['lat_pred'], c='red')
#ax3.title('Preditas')


fig.show()
